# %% [markdown]
# ## **° **

# %% [markdown]
# # Preguntas de introducción

# %% [markdown]
# ## **1° Dime la diferencia entre regio, dominio ad, dominio fd**
#
# En pocas palabras: una región tiene múltiples ADs y cada AD tiene múltiples FDs.

# %% [markdown]
# ## **2° Por que se escoge una region cercana al usuario?**
#
# Por baja latencia y alto desempeño

# %% [markdown]
# ## **3° a que se refiere gobernanza en OCI**
#
# Que gobierna, administra y regula los recursos de OCI

# %% [markdown]
# ## **4° Que es un container**
#
# Entonces, en las computadoras físicas de OCI existen dos espacios principales: uno es la **máquina virtual (VM)** y el otro es el **container**. Ambos comparten la misma computadora física, pero se **dividen e instancian por separado** para ejecutar diferentes aplicaciones o servicios de manera aislada.

# %% [markdown]
# ## **5° para que sirven Los compartimentos (Compartments)**
#
# Se utilizan para organizar y aislar recursos dentro de OCI.

# %% [markdown]
# # Cloud Computing

# %% [markdown]
# ## **1° Que es Tagging**
#
# ---
#
# Imagina que tienes una **gran bodega** donde guardas muchas cajas (tus **recursos en OCI**, como instancias, bases de datos, VCN, etc.).
#
# 🔹 El problema es que todas las cajas se parecen y pronto ya no sabes cuál pertenece a quién, cuál es de qué proyecto, o cuál usaste para un cliente específico.
#
# Aquí entran las **etiquetas (Tags)**:
#
# * Un **Tag** es como ponerle un **post-it o etiqueta adhesiva** a cada caja.
# * En la etiqueta puedes escribir información como:
#
#   * 📌 “Proyecto: Finanzas”
#   * 📌 “Ambiente: Producción”
#   * 📌 “Dueño: Luis”
#   * 📌 “Costo: Departamento A”
#
# Así, aunque la bodega sea enorme y tenga cientos de cajas, puedes **buscar, organizar y controlar** mejor todo lo que tienes.
#
# ---
#
# 👉 En OCI, **Tagging sirve para organizar y clasificar recursos**.
# Por ejemplo: puedes generar reportes de costos y saber exactamente cuánto gastó el **proyecto Finanzas** vs el **proyecto Ventas**, porque todos los recursos tenían su etiqueta.
#
# ---

# %% [markdown]
# ## **2° ¿Para que sirven las Quotas?**
#
# Claro, Luis 🙌
#
# Imagina que tienes un **edificio de oficinas** (tu **compartment** en OCI). Dentro de ese edificio trabajan diferentes equipos y cada uno puede pedir escritorios, computadoras, impresoras, etc. (estos son los **recursos de OCI**, como instancias, bases de datos, VCNs, etc.).
#
# Ahora, ¿qué pasa si un solo equipo decide llenar el edificio con 200 escritorios y no deja espacio para los demás? 😅
#
# Aquí es donde entran las **Quotas**:
#
# 👉 Las **Quotas son como las reglas del administrador del edificio** que dicen:
#
# * “El equipo de marketing solo puede tener hasta 10 escritorios.”
# * “El equipo de ventas solo puede usar 2 salas de juntas.”
# * “El equipo de desarrollo puede usar máximo 5 computadoras de alto rendimiento.”
#
# De esta forma, todos los equipos tienen recursos, nadie se excede y el edificio sigue organizado y justo.
#
# ---
#
# 📌 En analogía resumida:
#
# * **Edificio = Compartment**
# * **Recursos = escritorios, salas, computadoras**
# * **Quotas = reglas que limitan cuánto puede usar cada equipo**
#
# ---

# %% [markdown]
# ## **3° ¿Qué es un Bucket?**
#
# ¡Perfecto, Luis! 😃
#
# Imagina que tienes una **bodega enorme** donde puedes guardar cualquier cosa: cajas, maletas, muebles, etc. Esa **bodega** es como el **Object Storage** en OCI.
#
# Ahora bien, dentro de la bodega no quieres tener todo tirado y desordenado, así que decides poner **contenedores grandes de plástico** donde guardas tus cosas.
#
# 👉 Cada uno de esos **contenedores** es un **Bucket**.
#
# * Tú eliges qué metes dentro del contenedor (archivos, fotos, documentos, videos = **objetos**).
# * Puedes tener varios contenedores (varios **buckets**) para organizarte mejor, por ejemplo:
#
#   * Un bucket para tus fotos de viajes.
#   * Otro bucket para documentos importantes.
#   * Otro bucket para videos de trabajo.
# * Cada contenedor tiene su tapa y reglas: decides si lo dejas abierto para que todos lo vean o cerrado con llave (configuración de acceso).
#
# ---
#
# 📌 Analogía resumida:
#
# * **Object Storage = la bodega enorme**
# * **Bucket = el contenedor dentro de la bodega**
# * **Objetos = las cosas que guardas (archivos, datos, etc.)**
#
# ---

# %% [markdown]
# ## **4° Diferencia entre tipos De almacenamiento OS, AS, BS, FS**
#
# ¡Muy buena pregunta, Luis! Te lo voy a explicar primero **claro y técnico** y luego con una **analogía sencilla** para que quede bien grabado. 🚀
#
# ---
#
# ## 📌 Diferencias técnicas
#
# 1. **Object Storage**
#
#    * Guarda datos como **objetos (archivos + metadatos)**.
#    * Ideal para datos no estructurados (imágenes, videos, backups).
#    * Escalable y accesible vía API o web.
#
# 2. **Archive Storage**
#
#    * Es un tipo de **Object Storage pero para largo plazo**.
#    * Muy barato, pero el acceso es lento (se usa para archivos que no necesitas todos los días).
#    * Ejemplo: respaldos históricos, registros que debes guardar por ley.
#
# 3. **Block Storage**
#
#    * Se comporta como un **disco duro virtual** que puedes conectar a una máquina virtual.
#    * Ideal para bases de datos, sistemas operativos, aplicaciones que requieren **alta velocidad y baja latencia**.
#
# 4. **File Storage**
#
#    * Almacena datos como si fuera un **sistema de archivos compartido**.
#    * Varias instancias pueden acceder al mismo tiempo, como una carpeta compartida en red.
#    * Ideal para aplicaciones que necesitan acceso conjunto a los mismos archivos.
#
# ---
#
# ## 📌 Analogía (la de la casa)
#
# Imagina que tienes una **casa grande** y debes guardar cosas de distintas formas:
#
# 1. **Object Storage = clóset con cajas organizadas**
#
#    * Guardas cada cosa en una caja con etiqueta (archivos + metadatos).
#    * Puedes entrar rápido y buscar lo que quieras.
#
# 2. **Archive Storage = bodega en el sótano**
#
#    * Guardas cajas que casi nunca usas (archivos viejos).
#    * Mucho más barato, pero tardas en bajar y abrirlas si las necesitas.
#
# 3. **Block Storage = disco duro de tu computadora**
#
#    * Es como el **disco C:**, donde instalas programas y tienes el sistema operativo.
#    * Súper rápido, diseñado para trabajar en tiempo real.
#
# 4. **File Storage = carpeta compartida en la oficina**
#
#    * Varias personas pueden entrar a la misma carpeta y ver/modificar archivos.
#    * Ideal para colaboración.
#
# ---
#
# 👉 Resumen con la analogía:
#
# * **Object Storage** → tu clóset con cajas ordenadas.
# * **Archive Storage** → la bodega del sótano (lento pero barato).
# * **Block Storage** → el disco duro de tu PC.
# * **File Storage** → la carpeta compartida de la oficina.
#
# ---

# %% [markdown]
# ## **5° ¿Qué es un VCN?**
#
# Un **VCN (Virtual Cloud Network)** es como el **plano de calles y avenidas de una colonia privada**:
#
# * La **colonia privada** representa tu nube en OCI.
# * El **VCN** es el **mapa de calles** que organiza cómo se conectan las casas, oficinas o edificios (tus recursos como instancias, bases de datos, etc.).
# * Dentro del VCN tú decides:
#
#   * **Qué calles existen** (subnets).
#   * **Dónde poner las casetas de vigilancia** (security lists, NSG).
#   * **Qué salida conecta con la carretera principal** (Internet Gateway).
#   * **Cómo se enruta el tráfico** (Route Table).
#
# Sin ese mapa (VCN), cada casa/instancia estaría aislada sin manera de comunicarse ni con sus vecinos ni con el exterior.
#
# ---

# %% [markdown]
# ## **6° Subnet, Intarface y VNIC**
#
# Veo que mencionas directamente a las instancias, sin señalar que están dentro de una **subnet**; al menos esa es mi interpretación, pero podría estar equivocado.
#
# ¿Es más fácil mencionar solo el **interface** en lugar de decir “el interface de tal subnet”? Y si solo se menciona el **interface**, ¿se entiende que ya está dentro de una **subnet**?
#
# ---
#
# Muy buena observación 👌 y tienes razón en tu idea.
# Déjame desmenuzarlo con una analogía clara:
#
# ---
#
# Piensa otra vez en el **VCN como la colonia**:
#
# * La **subnet** sería como una **calle específica** dentro de esa colonia.
# * Una **instancia** sería como una **casa construida sobre esa calle**.
# * El **VNIC (interface)** sería como la **dirección postal de la casa** (número de calle, código postal, etc.), lo que permite que el cartero sepa dónde entregar cartas (red, tráfico de datos).
#
# ---
#
# 🔑 **Lo que pasa en OCI:**
#
# * Una instancia **siempre** está dentro de una **subnet** (no se puede quedar “flotando” en el VCN).
# * Y para conectarse a la red, **esa instancia necesita su VNIC**, que está obligatoriamente ligado a la subnet.
#
# Por eso, cuando en la práctica se dice **“la instancia tiene un VNIC”**, ya se entiende que está asociado a una subnet. No siempre es necesario repetirlo, porque es implícito.
#
# ---
#
# 👉 En resumen:
#
# * Sí, es más fácil mencionar solo el **interface (VNIC)**.
# * Y sí, al mencionarlo ya se da por entendido que ese interface está en **una subnet**.
#
# ---

# %% [markdown]
# ## **7° ¿Qué es una instancia de computo?**
#
# Claro. Una **instancia de cómputo** en OCI (o en cualquier nube) es básicamente una **máquina virtual** que corre en la nube. Es como un computador “virtual” que puedes usar para ejecutar aplicaciones, almacenar datos temporalmente o hacer cálculos, sin necesidad de tener un servidor físico en tus manos.
#
# Si quieres una **analogía**:
#
# * Imagina que el **data center de OCI** es un gran edificio de oficinas.
# * Cada **instancia de cómputo** sería como un escritorio con una computadora en ese edificio.
# * Tú puedes “sentarte” en ese escritorio (usar la instancia) para hacer tu trabajo (ejecutar aplicaciones o procesos), pero el escritorio no es fijo; puedes abrir otro en otra sala si necesitas más espacio o recursos.

# %% [markdown]
# ## **8° PaaS (Platform as a Service)**
#
# Es una **plataforma lista y administrada** que te da las herramientas necesarias (base de datos, middleware, entornos de desarrollo) para que solo te concentres en **crear y desplegar aplicaciones**, sin preocuparte por la infraestructura.
#
# 👉 **Ejemplo en OCI:** **Oracle Database Cloud Service** (base de datos administrada).
#
# ¿Quieres que también te lo resuma igual de corto para **IaaS** y **SaaS**, para que compares rápido los tres modelos?

# %% [markdown]
# ## **9° Relación correcta de jerarquía en OCI**
#
# Tenancy → Compartments → Regiones → AD → FD → Recursos

# %% [markdown]
# # Arquitectura OCI

# %% [markdown]
# ## **1° ¿Qué es un **FastConnect** en OCI?**
#
# Piensa en OCI como una **ciudad gigante en la nube**. Tus datos y aplicaciones son como **casas y negocios** dentro de esa ciudad. Normalmente, para llegar a la ciudad, usas **carreteras públicas**, compartidas con todos, que a veces pueden tener tráfico lento o cortes.
#
# Un **FastConnect** sería como construir una **autopista privada directa** desde tu casa o empresa hasta la ciudad. Esta autopista no se comparte con otros, es más rápida, segura y confiable, y te garantiza que siempre podrás llegar sin depender del tráfico de las carreteras públicas (Internet).
#
# En otras palabras: **FastConnect es una conexión dedicada y privada a OCI que hace el viaje de tus datos más rápido y seguro**.

# %% [markdown]
# ## **2° ¿Cómo funciona VNIC?**
#
# Imagina que tu **instancia de cómputo en OCI** es como un **departamento en un edificio**. Cada departamento necesita tener **acceso a la electricidad y al agua**, que representan los servicios de red y comunicación.
#
# El **VNIC (Virtual Network Interface Card)** sería como **el medidor de luz y agua del departamento**, que conecta tu departamento a la infraestructura del edificio. Gracias al medidor, tu departamento puede recibir electricidad y agua, pero también puedes controlar cuánto usas y cómo interactúas con otros departamentos.
#
# En términos de red: el VNIC **conecta tu instancia de cómputo a la red virtual (VCN)**, permitiéndole comunicarse con otras instancias, Internet o servicios dentro de OCI, mientras mantiene un control seguro y aislado del tráfico.

# %% [markdown]
# ## **3° ¿Para que es un Compartment?**
#
# Imagina que tu **cuenta de OCI** es como **una gran casa** con muchas habitaciones y cajones. Dentro de esa casa, tienes **distintos compartimentos (Compartments)** que funcionan como **cajones o closets**.
#
# Cada cajón guarda ciertas cosas: ropa, documentos, herramientas… De manera similar, cada **compartment** en OCI guarda **recursos de la nube** como instancias, bases de datos o buckets.
#
# Lo útil de los **compartments** es que te permiten:
#
# * **Organizar**: cada tipo de recurso tiene su “cajón” correspondiente.
# * **Aislar**: lo que guardas en un cajón no se mezcla con lo de otro, así puedes controlar acceso y seguridad.
# * **Controlar permisos**: puedes dar llave a ciertos “usuarios” solo para algunos cajones.
#
# En pocas palabras: un **compartment es como un cajón dentro de tu casa digital**, donde guardas y organizas tus recursos de manera segura y ordenada.

# %% [markdown]
# ## **4° ¿Qué es un Load Balancer en OCI?**
#
# Imagina que tienes un **restaurante muy popular** y llega **una fila enorme de clientes**. Si todos los clientes fueran a **un solo mesero**, ese mesero se saturaría y el servicio sería lento.
#
# Un **Load Balancer** funciona como un **jefe de piso** que **dirige a cada cliente al mesero disponible** para que todos sean atendidos de manera rápida y eficiente.
#
# En términos de OCI:
#
# * Los **clientes** son las solicitudes de los usuarios que llegan a tu aplicación.
# * Los **meseros** son las **instancias de cómputo** que procesan esas solicitudes.
# * El **Load Balancer** distribuye las solicitudes **uniformemente** entre todas las instancias disponibles para evitar sobrecargar una sola.
#
# En pocas palabras: un **Load Balancer es como un jefe de piso que reparte el trabajo entre varios meseros para que todos reciban atención rápida y sin retrasos**.

# %% [markdown]
# ## **5° ¿Qué son Security List Y Network Security Group (NSG)**
#
# Imagina que **tu red en la nube es un edificio de oficinas**.
#
# * Un **Security List** sería como **las reglas del edificio**:
#
#   * Determinan quién puede entrar o salir por **cada puerta del edificio** (subred).
#   * Todos los que usan esa puerta deben seguir las mismas reglas.
#
# * Un **Network Security Group (NSG)** sería como **un guardia de seguridad personal para cada oficina o cubículo**:
#
#   * Decide quién puede entrar o salir de **esa oficina específica** (instancia).
#   * Puedes tener reglas diferentes para cada oficina según lo que necesites proteger.
#
# En resumen:
#
# * **Security List → controla puertas del edificio (subred)**
# * **NSG → controla entradas de oficinas específicas (instancias)**

# %% [markdown]
# ## **6° ¿Cuál es la función de un Route Table en OCI?**
#
# Piensa en tu **VCN (Virtual Cloud Network)** como una **ciudad**. Dentro de esta ciudad hay muchas **calles** (subredes) y varias **casas** (instancias).
#
# El **Route Table** sería como **un mapa de rutas y señales de tránsito** que le dice a cada calle cómo llegar a otros lugares:
#
# * Por ejemplo, si una casa quiere enviar algo a otra ciudad (Internet), el **Route Table** indica qué camino tomar.
# * Si quiere comunicarse con otra subred dentro de la misma ciudad, también le dice la ruta correcta.
#
# En pocas palabras: **el Route Table decide cómo se enruta el tráfico de datos dentro de la red y hacia el exterior**, igual que un mapa decide por dónde deben ir los coches para llegar a su destino.

# %% [markdown]
# ## **7° Diferencia entre Load Balancer y Route Table**
#
# * El **Load Balancer** es como un recepcionista en la puerta de un edificio: recibe todas las solicitudes que vienen del exterior y las reparte a las diferentes oficinas (instancias) de manera equilibrada.
#
# * El **Route Table** (dentro de tu VCN) es como **el mapa de la ciudad y sus calles**: decide cómo viajan los autos (datos) **dentro de la ciudad** o hacia fuera. No decide quién entra al edificio, sino **cómo se mueven los datos dentro de la red y hacia Internet**.
#
# Así que ambos manejan tráfico, pero uno **gestiona el tráfico externo** hacia tus instancias, y el otro **gestiona el tráfico interno** y las rutas hacia afuera.

# %% [markdown]
# ## **8° ¿Qué es un Internet Gateway en OCI?**
#
# Un **Internet Gateway** en OCI es como **la puerta principal de tu vecindario** que conecta tu calle privada con la carretera principal de la ciudad (Internet).
#
# * Sin esa puerta, nadie de fuera puede entrar, y tus autos (datos) no pueden salir a la ciudad.
# * Con la puerta abierta, tus casas (instancias en la VCN) pueden comunicarse con el mundo exterior, recibir visitas o enviar correspondencia.
#
# En otras palabras, permite que los recursos dentro de tu **VCN** accedan a Internet y que Internet acceda a los recursos que tengan permiso.

# %% [markdown]
# ## **9° Que es un Componente es OCI**
#
# Imagina que **OCI (Oracle Cloud Infrastructure)** es como una **gran oficina de correos**.
#
# * Un **componente** en OCI sería como **cada parte o área de esa oficina** que tiene una función específica.
#
#   * Por ejemplo: el área donde reciben cartas, el área donde organizan paquetes, el área de atención al cliente, el área de computadoras para registrar envíos, etc.
#   * Cada “componente” tiene su propósito y trabaja junto con los otros componentes para que toda la oficina funcione correctamente.
#
# En OCI, los **componentes** son cosas como:
#
# * **VCN** → la red que conecta todo, como los pasillos que permiten que los empleados se muevan entre áreas.
# * **Subnet** → secciones de la oficina, como diferentes habitaciones dentro del edificio.
# * **Compartment** → cajones o archivadores donde guardas y organizas recursos.
# * **Load Balancer** → el encargado de repartir el trabajo entre varios empleados, como distribuir cartas entre varios carteros.
#
# En pocas palabras: un **componente en OCI es cualquier parte de la infraestructura en la nube que cumple una función específica dentro del sistema**.

# %% [markdown]
# ## **10° ¿Qué es una instancia?**
#
# - Cada **instancia de cómputo** es como **un empleado dentro de la oficina**.
# - Ese empleado tiene su **computadora, teléfono y escritorio**, y realiza tareas específicas, como procesar cartas, responder llamadas o revisar paquetes.
# - La oficina tiene **varios empleados** (instancias) que pueden trabajar al mismo tiempo, y todos siguen las **reglas de la oficina** (Security List, NSG, Route Tables) para que todo funcione de manera ordenada.
#
# En resumen:
# - **Instancia = un trabajador que hace el trabajo concreto** dentro de la infraestructura de la nube.
# - Puede haber muchas instancias haciendo el mismo trabajo o tareas distintas, pero todas dependen de la infraestructura que las rodea para poder operar.
#
# **¿Y en este caso de la analogía cuál sería la oficina? El VCN seria el mapa, la instancia sería la persona que trabaja, pero la oficina que sería?**
#
# * **VCN (Virtual Cloud Network)** → sería **el edificio completo** donde trabajan todos los empleados. Dentro de este edificio hay diferentes salas, pasillos y reglas de acceso. Es la **infraestructura de red** que conecta todo.
# * **Subnet (Oficina)** → sería **una sala o área dentro del edificio**. Algunas salas pueden ser públicas (con acceso directo a la calle/Internet) y otras privadas (solo accesibles desde dentro del edificio).
# * **Instancia** → sería **el empleado que realiza tareas dentro de la sala**.
# * **Compartment** → sería **un cajón de archivos o una caja organizadora de la oficina**, donde se guardan documentos importantes. No hace el trabajo, pero ayuda a mantener todo ordenado.
# * **Load Balancer** → sería **el recepcionista de la oficina**, que distribuye las solicitudes de los clientes a los diferentes empleados para que ninguno se sobrecargue.

# %% [markdown]
# # IAM -Identity and Access Management

# %% [markdown]
# ## **1° ¿Qué son policies statements**
#
# ¡Claro! Vamos a ponerlo de manera sencilla con una analogía:
#
# Imagina que estás en **un edificio de oficinas**:
#
# * Cada **recurso** (bases de datos, máquinas virtuales, almacenamiento) es como **una oficina o sala dentro del edificio**.
# * Cada **usuario** o grupo de usuarios es como **una persona o un equipo que trabaja en el edificio**.
# * Una **policy statement** es como **una regla escrita en un cartel que dice quién puede entrar a qué oficina y qué puede hacer dentro**.
#
# Por ejemplo:
#
# > “El equipo de contabilidad puede **entrar a la oficina de finanzas** y **leer los archivos**, pero no puede **modificar nada**.”
#
# En OCI IAM:
#
# * La **policy statement** define **quién (usuario/grupo)** puede hacer **qué (acción)** sobre **qué recurso**.
# * Se escribe con la estructura básica:
#
# ```
# Allow <grupo> to <acción> on <recurso>
# ```
#
# Así, cada policy statement es **una instrucción clara que otorga permisos específicos**, igual que las reglas en un edificio sobre quién puede usar cada sala y qué puede hacer allí.

# %% [markdown]
# ## **2° ¿Qué es **dynamic group** en IAM?**
#
# Imagina que estás en **un parque de diversiones**:
#
# * Tienes **áreas restringidas**, como la montaña rusa VIP, la sala de control o el área de mantenimiento.
# * Cada **persona** puede tener **distintos roles**: visitante, empleado de limpieza, operador de juegos, seguridad.
#
# Un **dynamic group** sería como un **grupo que se forma automáticamente según ciertas características de la persona**:
#
# * Por ejemplo, “**todos los que llevan uniforme de operador de juegos**” o “**todos los que están en el área de mantenimiento**”.
# * No necesitas agregar manualmente a cada persona al grupo; **el grupo se actualiza automáticamente** según quién cumpla con las condiciones.
#
# En OCI IAM:
#
# * Un **dynamic group** agrupa **usuarios o recursos (como instancias de cómputo)** según **atributos que cumplen ciertas reglas**.
# * Luego puedes usar este grupo en una **policy statement** para dar permisos:
#
# ```
# Allow dynamic-group <nombre> to <acción> on <recurso>
# ```
#
# 💡 Resumen de la analogía:
#
# * **Dynamic group = grupo “mágico” que se forma solo con los que cumplen ciertas características**.
# * No tienes que estar actualizando la lista manualmente; OCI lo hace por ti.

# %% [markdown]
# ## **3° ¿Qué es tenancy?**
#
# En pocas palabras, **tenancy** es como la “cuenta principal” de tu organización en OCI: contiene **todos los recursos, usuarios y compartimentos**.
#
# Analógicamente, sería **el edificio completo** donde están todas las oficinas (compartimentos) y trabajadores (usuarios/instancias).

# %% [markdown]
# ## **4° Diferencia entre tenancy y VCN**
#
# **tenancy** y **VCN** son cosas completamente diferentes:
#
# * **Tenancy**: Es la **cuenta principal** de tu organización en OCI. Contiene **todos los recursos, compartimentos y usuarios**. Es como **el edificio entero** donde está todo.
# * **VCN (Virtual Cloud Network)**: Es una **red privada virtual** dentro de tu tenancy. Conecta instancias de cómputo y otros recursos. Es como **el sistema de pasillos y conexiones dentro del edificio** que permite que las oficinas (subnets) y trabajadores (instancias) se comuniquen.
#
# En resumen: la **tenancy es el edificio completo**, y el **VCN es la red de caminos dentro del edificio**.

# %% [markdown]
# ## **5° Lenguaje para escribir policy**
#
# En el contexto de **OCI IAM**, cuando hablamos del “tipo de lenguaje” para escribir una **policy**, podemos usar varios términos que se refieren a lo mismo:
#
# * **Declarative language** (lenguaje declarativo) → porque defines *qué se permite* o *qué se restringe*, no cómo se hace.
# * **Policy language** → lenguaje específico para políticas de IAM.
# * **Human-readable language** / **Human-friendly language** → lenguaje que es comprensible para humanos.
# * **DSL (Domain-Specific Language)** → lenguaje específico del dominio de gestión de identidades y accesos.
# * **Statements language** → lenguaje basado en declaraciones (statements) que indican acciones, recursos y sujetos.
#
# En la práctica, la mayoría de la gente lo describe como “**lenguaje entendible para humanos**” o “**lenguaje declarativo para políticas**”.

# %% [markdown]
# ## **6° Dynamic Groups**
#
# - Grupo de **recursos**, no de personas.
# - Permite asignar permisos automáticamente a instancias o recursos según reglas o etiquetas.
# - Ejemplo: Todas las instancias con `env=producción` pueden acceder a cierto almacenamiento.
#
# ## **7° OCI CLI**
# - Herramienta de **línea de comandos** para gestionar usuarios, grupos, políticas y recursos.
# - Permite crear, modificar o consultar recursos sin usar la consola web.
# - Ejemplo: Crear un usuario o asignarle permisos a un grupo desde el terminal.

# %% [markdown]
# # AuthN AuthZ

# %% [markdown]
# ## **1° Tipos de credenciales parainstancias**
#
# Claves API y certificados de instancia

# %% [markdown]
# ## **2° Métodos para autenticarse**
#
# - Nombre de usuario y contraseña
# - Claves API
# - Autenticación federada (SSO)

# %% [markdown]
# # VCN

# %% [markdown]
# ## **1° Diferencia entre los Gateway**
#
# **a) NAT Gateway**
#
# * **Qué hace:** Permite que las **instancias privadas** (sin IP pública) salgan a Internet **solo para iniciar conexiones**, pero **nadie desde Internet puede entrar**.
# * **Analogia:** Es como cuando **llamas por teléfono usando número oculto**: tú puedes marcar y hablar, pero la otra persona **no puede devolverte la llamada directamente** porque no ve tu número real.
#
# ---
#
# **b) Service Gateway**
#
# * **Qué hace:** Permite que tu red privada se conecte a **servicios de OCI** (como Object Storage, Autonomous Database, etc.) **sin pasar por Internet**.
# * **Analogia:** Es como un **pasillo interno exclusivo** en un centro comercial que conecta tu tienda directamente con el almacén central, sin salir a la calle.
#
# ---
#
# **c) Internet Gateway**
#
# * **Qué hace:** Conecta tu VCN con Internet de forma **bidireccional**. Las instancias con IP pública pueden enviar y **recibir tráfico desde Internet**.
# * **Analogia:** Es como **la puerta principal de tu casa**: puedes salir y también cualquiera puede tocar el timbre y entrar si lo permites.
#
# ---
#
# **d) Local Peering Gateway (LPG)**
#
# * **Qué hace:** Permite la comunicación **privada** entre **dos VCNs en la misma región**, sin usar Internet ni VPN.
# * **Analogia:** Es como abrir un **puente privado** entre dos colonias vecinas para que los residentes puedan visitarse sin salir a la carretera principal.
#
# ---
#
# 📌 **Resumen rápido:**
#
# * **NAT Gateway** → Salida privada hacia Internet (solo de dentro hacia afuera).
# * **Service Gateway** → Acceso a servicios de OCI sin pasar por Internet.
# * **Internet Gateway** → Conexión abierta bidireccional con Internet.
# * **Local Peering Gateway** → Comunicación privada entre dos VCNs en la misma región.

# %% [markdown]
# ## **2° ¿Qué recurso controla el tráfico entrante y saliente en un VCN?**
#
# La respuesta correcta es:
#
# ✅ **b) Security List**
#
# 👉 En OCI, las **Security Lists** (o Network Security Groups) son las que **controlan el tráfico entrante y saliente** mediante reglas de seguridad (puertos, protocolos, origen/destino).
#
# * **Route Table** → decide la **ruta** que seguirá el tráfico, pero no lo bloquea ni permite por sí sola.
# * **Internet Gateway** → conecta el VCN a Internet, pero no controla puertos ni protocolos.
# * **Firewall de la aplicación** → se refiere a algo dentro del sistema/aplicación, no al nivel de red en OCI.
#
# 📌 Truco de memoria:
#
# * **Security List = policía en la puerta** (decide quién entra y quién sale).
# * **Route Table = GPS** (decide por dónde se va).

# %% [markdown]
# ## **3° Diferencia de Security List y Load Balancer**
#
# Muy buena pregunta 👌
#
# En **OCI (Oracle Cloud Infrastructure)**, tanto **Security List** como **Load Balancer** se relacionan con el tráfico de red, pero cumplen funciones muy diferentes:
#
# ---
#
# 🔹 **Security List**
#
# * **Qué es:** Un conjunto de **reglas de firewall virtual** que se aplican a las **subredes** de un VCN (Virtual Cloud Network).
# * **Función:** Controla el **tráfico entrante y saliente** (inbound y outbound) a nivel de red.
# * **Nivel de aplicación:** Se aplica a todos los recursos (instancias, bases de datos, etc.) que están dentro de la subred.
# * **Ejemplo:**
#
#   * Permitir tráfico entrante en el puerto 22 (SSH).
#   * Bloquear tráfico saliente hacia internet en el puerto 25 (SMTP).
#
# En resumen, define **quién puede entrar y salir** de la subred.
#
# ---
#
# 🔹 **Load Balancer**
#
# * **Qué es:** Un servicio gestionado que distribuye automáticamente el tráfico entrante entre varias instancias backend.
# * **Función:** Proporciona **alta disponibilidad y escalabilidad** distribuyendo las peticiones entre servidores para balancear la carga.
# * **Nivel de aplicación:** Opera como un **punto de entrada único** para el tráfico externo o interno hacia tus aplicaciones.
# * **Ejemplo:**
#
#   * Si tienes 3 instancias corriendo una aplicación web, el Load Balancer reparte las solicitudes HTTP/HTTPS entre ellas.
#   * Puede verificar la salud de cada instancia para no enviar tráfico a las que fallen.
#
# En resumen, asegura que el **tráfico se distribuya** de manera eficiente entre tus servidores.
#
# ---
#
# ✅ **Diferencia clave**:
#
# * **Security List** = seguridad (qué tráfico está permitido o bloqueado).
# * **Load Balancer** = distribución (cómo se reparte el tráfico entre instancias).
#
# ---

# %% [markdown]
# ## 4° Route Table
#
# Piensa en el **VCN** como si fuera una **ciudad** y las **subnets** fueran **barrios** dentro de esa ciudad.
#
# Ahora…
#
# 🛣️ **Route Table (Tabla de enrutamiento)**
# Es como el **mapa de calles y autopistas** que le dice a los carros (los paquetes de datos) por dónde deben ir para llegar a su destino.
#
# ---
#
# 🔹 **Ejemplo de analogía:**
# - Si estás en el **barrio A (subnet privada)** y quieres ir al **centro comercial (Internet)**, el mapa te dice:
#   👉 “Para llegar al centro comercial, debes salir por la **puerta principal (Internet Gateway)**”.
#
# - Si estás en el **barrio B (subnet privada)** y quieres ir a la **bodega municipal (Object Storage de OCI)**, el mapa dice:
#   👉 “Para llegar a la bodega, toma la salida hacia el **Service Gateway**”.
#
# - Si desde el **barrio C** quieres comunicarte con otra **ciudad (otro VCN)**, el mapa dirá:
#   👉 “Para ir a esa ciudad, usa la **salida al LPG o DRG**”.
#
# ---
#
# 📌 Sin ese mapa (Route Table), los autos (paquetes) **no sabrían por dónde salir ni a dónde ir**, incluso si la ciudad tuviera puertas.
#
# ---
#
# 👉 En resumen:
# - **Subnets** = barrios.
# - **Gateways** = puertas de salida.
# - **Route Table** = el mapa que dice cuál puerta usar según el destino.
#
# ---

# %% [markdown]
# ## 5° Load Balancer vs Route Table
#
# * **Route Table** = mapa de caminos que dice **por dónde debe ir el tráfico** desde una subnet hacia destinos específicos (Internet, otro VCN, servicios de OCI).
# * **Load Balancer** = agente que recibe el tráfico y **decide a qué servidor/instancia específico enviarlo** para balancear la carga y evitar saturación.
#
# 💡 Resumen rápido:
#
# * **Route Table → el camino**
# * **Load Balancer → el destino dentro de ese camino**
#
# ---
#
# * **Route Table** → indica **por dónde ir**.
# * **Load Balancer** → indica **a quién llegar**.
#
# Básicamente: **camino vs destino**.
#
# ---
#
# ## 6° Orden de trafico
#
# ---
#
# 🔹 Flujo correcto:
#
# 1. **Route Table**
# - Cuando un paquete de datos **sale de una subnet**, la **Route Table** primero decide **por qué puerta (gateway) debe salir** según el destino.
# - Ejemplo: hacia Internet → Internet Gateway; hacia otro VCN → DRG; hacia Object Storage → Service Gateway.
#
# 2. **Load Balancer**
# - Una vez que el tráfico llega a un **punto de entrada que es el Load Balancer**, este decide **a qué instancia backend enviar cada solicitud**, basándose en carga, salud de la instancia, etc.
#
# ---
#
# 🔹 Analogía de la ciudad:
#
# - **Route Table** = el **mapa que dice por qué salida del barrio salir** para llegar a otra ciudad o lugar.
# - **Load Balancer** = la **glorieta o semáforo al llegar al destino**, que decide a qué calle exacta (instancia) mandar cada carro.
#
# ---
#
# 💡 Resumen:
# **Primero la Route Table indica el camino**, luego el **Load Balancer decide el destino exacto dentro del camino**.
#
# ---

# %% [markdown]
# # Security List y NSG

# %% [markdown]
# ## **1° Diferencias de Security List y NSG**
#
# * **SL = Subred completa** → reglas “globales” para toda la subred.
# * **NSG = Instancia o grupo de instancias** → reglas “personalizadas” por recurso.

# %% [markdown]
# ## **2° NSG puede tener reglas de ingreso y egreso**
#
# ¡Sí, exactamente! ✅
#
# Un **NSG (Network Security Group)** puede tener **reglas de ingreso (ingress) y egreso (egress)**:
#
# Esto significa que puedes especificar, por ejemplo:
#
# * Solo permitir que ciertas IPs accedan a un puerto específico (ingreso).
# * Solo permitir que la instancia se comunique con ciertos servidores externos (egreso).
#
# En cambio, recuerda que una **Security List** también tiene reglas de ingreso y egreso, pero **se aplican a toda la subred**, no a instancias individuales.

# %% [markdown]
# ## **3° ¿Qué recurso se debe asociar a un NSG para aplicar sus reglas?**
#
# VNIC (Virtual Network Interface Card)

# %% [markdown]
# ## **4° ¿Cuál es el estado predeterminado de una Security List recién creada?**
#
# El estado de una **Security List** recién creada en OCI es:
#
# **⚠️ Niega todo el tráfico entrante y saliente** hasta que agregues reglas.
#
# * No permite tráfico por defecto.
# * Debes crear reglas de **ingreso (ingress)** y **egreso (egress)** para que las instancias en la subred puedan comunicarse.
#
# 💡 **Forma fácil de recordarlo:**
# “**Por defecto, Security List es bloqueadora.**” → nada pasa hasta que tú lo permitas.

# %% [markdown]
# ¡Claro, Luis! Vamos a enfocarnos en las preguntas que contestaste incorrectamente y sus conceptos clave:
#
# ---
#
# ## **5: Elemento que NO forma parte de una regla de Security List o NSG**
#
# **Tipo de instancia (VM o bare metal)**
# * **Concepto:**
#   Las reglas de Security List o NSG **definen tráfico**, no tipos de instancias.
#   Cada regla incluye:
#
#   * **Protocolo:** TCP, UDP, ICMP
#   * **Rango de puertos:** Ej. 22 para SSH, 80 para HTTP
#   * **Dirección de origen o destino:** IP o rango de IP
#     El tipo de instancia **no se usa para filtrar tráfico**, por eso no forma parte de la regla.
#
# ---
#
# ## **6: Si una instancia no tiene NSG, ¿aún puede recibir tráfico según la Security List?**
#
# * **Concepto:**
#
#   * Las **Security Lists** se aplican a nivel de **subnet**, por lo que todas las instancias dentro de esa subnet reciben el tráfico permitido por las reglas de la Security List.
#   * Las **NSG** son opcionales y aplican control adicional **a nivel de instancia**.
#   * Por lo tanto, aunque no tengas NSG, si la Security List lo permite, el tráfico **sí llega a la instancia**.

# %% [markdown]
# ## 7° Puertos
#
# * Piensa en los **puertos** como **puertas de una casa**. Cada puerta sirve para un propósito:
#
#   * **Puerta 22** → SSH (administración remota)
#   * **Puerta 80** → HTTP (sitios web sin HTTPS)
#   * **Puerta 443** → HTTPS (sitios web seguros)
#   * **Puerta 3306** → MySQL (bases de datos)
#
# * Cada puerto permite que **un tipo de tráfico específico** pase a la instancia.
#
# ---
#
# ## 8° **Tipos de tráfico**
#
# * **TCP** → tráfico confiable, como cartas certificadas: llegan completas y en orden.
# * **UDP** → tráfico rápido, como mensajes de voz: puede que algo se pierda, pero es más veloz.
# * **ICMP** → tráfico de red para “ping” o mensajes de error.
#
# Cuando creas una regla, debes indicar **protocolo + puerto**.
#
# ---
#
# ## 9° **Ingress (tráfico entrante)**
#
# * Son las **reglas que permiten que alguien entre a tu red o instancia**.
# * Analogía:
#
#   * Tu casa tiene un **portero** que revisa **quién puede entrar** por cada puerta (puerto).
#   * Ejemplo: Ingress TCP puerto 22 → permite que alguien haga SSH.
#
# ---
#
# ## 10° **Egress (tráfico saliente)**
#
# * Son las **reglas que permiten que tu red o instancia salga hacia afuera**.
# * Analogía:
#
#   * Tu casa tiene reglas de salida: “solo se puede enviar cartas a ciertos destinos”
#   * Ejemplo: Egress TCP puerto 80 → tu servidor puede conectarse a internet para HTTP.
#
# ---
#
# ## 11° **Combinación de puertos, protocolo y tipo de tráfico**
#
# Cuando creas una regla en **Security List o NSG**, normalmente defines:
#
# 1. **Tipo de tráfico:** TCP, UDP, ICMP
# 2. **Puerto o rango de puertos:** 22, 80, 443, etc.
# 3. **Dirección:**
#
#    * Ingress → de fuera hacia la instancia/subnet
#    * Egress → de la instancia/subnet hacia afuera
# 4. **Origen o destino:**
#
#    * IP específica, rango de IPs o etiqueta (en NSG)
#
# ---
#
#  🔹 Ejemplo práctico:
#
# * Quiero permitir que cualquier persona pueda ver mi web:
#
#   * **Tipo de tráfico:** TCP
#   * **Puerto:** 80
#   * **Dirección:** Ingress
#   * **Origen:** 0.0.0.0/0 (cualquier IP)
#
# * Quiero que mi servidor pueda conectarse a internet para actualizaciones:
#
#   * **Tipo de tráfico:** TCP
#   * **Puerto:** 443
#   * **Dirección:** Egress
#   * **Destino:** 0.0.0.0/0
#
# ---

# %% [markdown]
# # Load Balancer

# %% [markdown]
# ---
#
# ## **1° Tráfico que maneja el Load Balancer**
# 👉 El Load Balancer de OCI no solo sirve para páginas web (HTTP/HTTPS), también puede balancear tráfico TCP.
# Eso significa que puede manejar aplicaciones que no usan HTTP, como bases de datos o aplicaciones personalizadas.
#
# ---
#
# ## **2° Capas en las que trabaja el Load Balancer**
# 👉 Un Load Balancer puede trabajar en **dos niveles del modelo OSI**:
#
# * **Capa 4 (Transporte):** distribuye el tráfico basándose en la conexión TCP (sin mirar qué hay dentro del mensaje).
# * **Capa 7 (Aplicación):** entiende el contenido del tráfico (por ejemplo, HTTP/HTTPS) y puede tomar decisiones más inteligentes, como redirigir según la URL o el encabezado.
#
# ---
#
# ## **3° Quién procesa las solicitudes**
# 👉 El **Listener** es como la “puerta” que recibe las conexiones.
# 👉 Pero el que **organiza y reparte las solicitudes a los servidores backend** es el **Backend Set**, que define:
#
# * Qué servidores hay (backends).
# * Cómo se reparte el tráfico (round robin, etc.).
# * Cómo verificar si un servidor está sano (health checks).

# %% [markdown]
# # Computing

# %% [markdown]
# ## **1° ¿Qué es un Compute Instance?**
#
# 👉 Es básicamente una **máquina en la nube**. Puede ser:
#
# * **Máquina virtual (VM):** corre sobre hardware compartido.
# * **Bare metal:** tienes todo el servidor físico solo para ti.
#   Sirve para ejecutar tus aplicaciones, servicios, bases de datos, etc.

# %% [markdown]
# ## **2° Conexión por SSH**
#
# 👉 Para entrar a tu instancia desde tu computadora usas **SSH** (consola segura).
# Para eso necesitas un **par de llaves criptográficas**:
#
# * **Clave pública:** se guarda en la instancia.
# * **Clave privada:** la usas en tu computadora para conectarte.
#   Esto da seguridad, porque solo quien tenga la clave privada correcta puede acceder.

# %% [markdown]
# ## **3° Almacenamiento persistente**
#
# 👉 Una instancia de Compute puede usar dos tipos de almacenamiento:
#
# * **Local Temp Storage:** muy rápido, pero se borra si la instancia se detiene o termina.
# * **Block Volumes:** discos virtuales que puedes adjuntar a la instancia, y **los datos no se pierden** aunque apagues la máquina.
#   Por eso, si quieres **guardar datos a largo plazo**, usas **Block Volumes**.

# %% [markdown]
# ## **4° Dónde se despliega la instancia**
#
# 👉 Una instancia de Compute **siempre vive dentro de un VCN (Virtual Cloud Network)** y más específicamente en una **subnet**.
# Esto es como decir que tu máquina en la nube necesita una **red privada virtual** para poder comunicarse con Internet o con otras instancias.
#
# ---

# %% [markdown]
# 📌 Resumen simplificado:
#
# * **Compute Instance = tu máquina en la nube.**
# * **Acceso SSH = con llaves pública/privada.**
# * **Almacenamiento persistente = Block Volumes.**
# * **Red = siempre dentro de un VCN/subnet.**

# %% [markdown]
# ---
#
# ## **5: Tipos de almacenamiento para Compute**
#
# * **Concepto clave:** Una instancia de **Compute** puede usar diferentes tipos de almacenamiento según tus necesidades:
#
#   1. **Local NVMe:** almacenamiento físico muy rápido **dentro de la propia máquina**. Se borra si se termina la instancia.
#   2. **Block Volumes:** discos virtuales **persistentes**, independientes de la instancia. Se pueden expandir, respaldar y mover entre instancias.
#   3. **Object Storage:** almacenamiento en la nube **para archivos y datos no estructurados**. No se monta directamente como disco, pero la instancia puede acceder a él para guardar o leer datos.
#
# **Idea clave:** Compute es flexible y puede combinar estos tres tipos según el uso: rendimiento local, persistencia y almacenamiento masivo.
#
# ---
#
# ## **6: Herramienta para administrar Compute**
#
# OCI CLI
# * **Concepto clave:**
#
#   * **OCI CLI (Command Line Interface):** permite **crear, configurar y administrar recursos de OCI**, incluyendo instancias de Compute, VCN, Block Volumes, Load Balancers, etc.
#   * **kubectl** se usa **solo para Kubernetes** (OKE) y no para instancias individuales de Compute.
#
# **Idea clave:** Siempre que quieras manejar **instancias de Compute desde la línea de comandos**, la herramienta oficial es **OCI CLI**.
#
# ---

# %% [markdown]
# # Instancias

# %% [markdown]
# ## **1° Tipos de instancias**
#
# 👉 En OCI, puedes crear dos tipos de instancias:
#
# * **Máquinas virtuales (VMs):** comparten hardware con otras instancias, pero están aisladas entre sí. Son flexibles y fáciles de escalar.
# * **Bare metal:** te dan **todo un servidor físico** solo para ti. Esto es útil si necesitas mucha potencia o control total del hardware.
#   💡 Concepto clave: las instancias son **máquinas en la nube**, pero el tipo que elijas define si compartes hardware o lo tienes dedicado.

# %% [markdown]
# ## **2° Shape de una instancia**
#
# 👉 Un **shape** determina la “potencia” de tu instancia. Es decir, cuánto:
#
# * **CPU**
# * **Memoria RAM**
# * **Red (ancho de banda)** tendrá tu máquina.
#
# 💡 Concepto clave: **Shape = recursos asignados a la instancia**, no es la imagen ni la red. Es como escoger el tamaño del motor de un coche según tus necesidades.

# %% [markdown]
# ## **3° Qué se necesita para crear una instancia**
#
# 👉 Para lanzar una instancia necesitas varias cosas:
#
# 1. **Imagen del sistema operativo:** Linux, Windows, etc., que será tu entorno de trabajo.
# 2. **Shape:** la cantidad de CPU, RAM y red.
# 3. **VCN y subnet:** la instancia necesita estar dentro de una red virtual para poder comunicarse con otras instancias o con Internet.
# 4. **Clave pública SSH:** para conectarte de forma segura si la instancia es Linux o Unix.

# %% [markdown]
# # Scaling

# %% [markdown]
# ## **1° ¿Qué es autoscaling en OCI y para qué sirve?**
#
# * **Autoscaling** = ajustar automáticamente los recursos de una aplicación según la carga de trabajo.
# * Si hay **más demanda**, se agregan recursos (más instancias o más capacidad).
# * Si baja la demanda, se reducen recursos para **ahorrar costos**.
#
#   👉 Lo importante: ocurre automáticamente según reglas que tú configures.

# %% [markdown]
# ## **2° Diferencia entre scaling horizontal y vertical**
#
# * **Horizontal scaling**: agregar o quitar **más instancias** del mismo tipo.
#   Ejemplo: pasar de 2 servidores a 5 servidores.
# * **Vertical scaling**: cambiar el tamaño de **una sola instancia**.
#
#   Ejemplo: aumentar una máquina de 2 CPUs a 8 CPUs.
#
#   👉 Diferencia clave: horizontal = más máquinas, vertical = una máquina más potente.

# %% [markdown]
# ## **3° ¿Qué se necesita para autoscaling en una instance pool?**
#
# * Lo fundamental es tener **políticas de scaling**.
# * Estas políticas son reglas que dicen:
#
#   * *Si el CPU pasa de 70%, agrega 2 instancias*.
#   * *Si baja del 30%, elimina 1 instancia*.
#
# * El Load Balancer puede ayudar a repartir la carga, pero **lo obligatorio son las políticas** para que autoscaling se active.

# %% [markdown]
# 📌 **En resumen**:
#
# * Autoscaling ajusta los recursos automáticamente.
# * Scaling horizontal = más instancias, vertical = una más potente.
# * Lo esencial para autoscaling son **las políticas de scaling**.

# %% [markdown]
# ---
#
# ## **4. Las instancias de un Instance Pool deben ser del mismo tipo (shape)**
#
# * **Concepto:** Todas las instancias dentro de un **Instance Pool** deben ser del mismo **shape** (misma combinación de CPU, memoria y red) para que el escalamiento automático funcione correctamente.
#
# ---
#
# ## **5. Métrica común para activar el escalamiento automático**
#
# CPU utilization.
# * **Concepto:** El **autoscaling** se activa generalmente usando métricas de rendimiento, como **CPU, memoria o carga de red**, no el número de buckets de Object Storage.
#
# ---
#
# ## **6. scale-in/out**
#
# * **Concepto:**
#
#   * **Scale-out:** Agrega instancias (aumenta capacidad).
#   * **Scale-in:** Reduce instancias (disminuye capacidad) para optimizar recursos y costos.
#
# ---

# %% [markdown]
# # Kubernetes

# %% [markdown]
# ## **1° ¿Qué es OKE?**
#
# * OKE es un **servicio administrado de Kubernetes** en OCI.
# * Normalmente, si montas Kubernetes tú mismo, tienes que instalar y administrar todo: control plane, nodos, seguridad, red, etc.
# * Con OKE, Oracle se encarga de lo más pesado (el **control plane**) y tú solo administras tus aplicaciones y los **worker nodes**.
#
#   👉 Lo hace más sencillo, seguro y escalable.

# %% [markdown]
# ## **2° Control Plane (plano de control)**
#
# * El **control plane** es el cerebro de Kubernetes.
# * Se encarga de:
#
#   * Decidir en qué nodo correrán tus pods.
#   * Monitorear el estado del clúster.
#   * Escalar aplicaciones cuando es necesario.
# * En OKE **no tienes que administrarlo**: Oracle lo gestiona automáticamente.
#
#   👉 Tú solo te enfocas en los **worker nodes** (las máquinas que realmente ejecutan los contenedores).

# %% [markdown]
# ## **3° Container Registry (OCIR)**
#
# * Para ejecutar contenedores necesitas imágenes (ej. `nginx:latest`, `miapp:v1`).
# * En OCI esas imágenes se guardan en **Oracle Cloud Infrastructure Registry (OCIR)**.
# * Es un repositorio privado y seguro (tipo Docker Hub, pero en OCI).
#
#   👉 Desde ahí OKE toma las imágenes para desplegar los contenedores en el clúster.

# %% [markdown]
# ## **4° kubectl**
#
# * **kubectl** es la herramienta oficial de línea de comandos para Kubernetes.
# * Con ella puedes:
#
#   * Crear pods, servicios, deployments.
#   * Escalar aplicaciones.
#   * Ver el estado del clúster.
# * En OKE, después de configurar las credenciales, usas `kubectl` para hablar con tu clúster.
#   👉 Ejemplo:
#
# ```bash
# kubectl get pods
# ```
#
# Te muestra todos los pods corriendo en tu clúster OKE.
#
# ---
#
# 🔑 **Resumen en una frase:**
# OKE = servicio administrado de Kubernetes en OCI, donde Oracle maneja el control plane, tú usas OCIR para guardar imágenes, y `kubectl` para desplegar y administrar aplicaciones en tus worker nodes.

# %% [markdown]
# # Cointener Instance

# %% [markdown]
# ¡Muy buena pregunta, Luis! 🚀
# En el examen de **OCI Foundation**, además de OKE, también aparece el servicio **Container Instances**, que es diferente y mucho más sencillo.
#
# Aquí te dejo los **conceptos clave de Container Instances en OCI** 👇
#
# ---
#
# ## 🔹 1. ¿Qué es una Container Instance?
# - Es un **servicio serverless para ejecutar contenedores sin necesidad de administrar servidores (VMs) o clústeres de Kubernetes**.
# - OCI se encarga de la infraestructura: tú solo defines la imagen del contenedor y las configuraciones.
#
# 👉 Piensa en él como un “contenedor listo para usar” sin tener que preocuparte por nodos, clusters o Kubernetes.
#
# ---
#
# ## 🔹 2. Diferencia con OKE
# - **OKE (Oracle Kubernetes Engine):** es para despliegues grandes y complejos, cuando necesitas un clúster Kubernetes completo.
# - **Container Instances:** es más simple, ideal para pruebas, microservicios pequeños o apps que no necesitan todo un clúster.
#
# ---
#
# ## 🔹 3. Integración con OCI
# - Puede usar imágenes desde **OCI Registry (OCIR)** o **Docker Hub**.
# - Se ejecuta dentro de un **VCN**, por lo que puede conectarse a bases de datos, Object Storage u otros servicios.
# - Se puede controlar acceso con **IAM Policies**.
#
# ---
#
# ## 🔹 4. Uso típico
# - Desplegar microservicios ligeros.
# - Probar aplicaciones en contenedores rápidamente.
# - Ejecutar procesos batch o jobs sin levantar VMs completas.
#
# ---
#
# ## 🔹 5. Beneficios principales
# - **Serverless:** no administras infraestructura.
# - **Escalable:** puedes lanzar varias instancias de contenedor según la carga.
# - **Rápido:** se levantan más rápido que una VM o un clúster de Kubernetes.
#
# ---
#
# 🔑 **Resumen en una frase:**
# *Container Instances en OCI = forma rápida y serverless de ejecutar contenedores directamente, sin necesidad de administrar VMs o Kubernetes.*

# %% [markdown]
# ¡Claro! Vamos a desglosar las **preguntas que respondiste incorrectamente** (4 y 9) y sus conceptos, para que quede muy claro:
#
# ---
#
# ## **6: Recurso para que los pods ingresen a internet**
#
# **Pregunta:**
#
# > ¿Qué recurso de OCI se puede usar para que los pods de un clúster OKE puedan acceder a Internet?
#
# **Tu respuesta:** Internet Gateway (B)
# **Respuesta correcta:** NAT Gateway (C)
#
# **Concepto:**
#
# * Un **Internet Gateway (IGW)** permite que recursos dentro de tu **VCN** sean accesibles **desde Internet**. Es decir, el tráfico entra desde Internet hacia tu red.
# * Un **NAT Gateway** permite que los recursos **privados de tu red (como los pods de OKE en subnets privadas)** puedan salir a Internet para actualizar paquetes o conectarse a servicios externos, **sin exponerlos directamente a Internet**.
# * En OKE, normalmente tus pods corren en subnets privadas, así que necesitan un **NAT Gateway** para acceder a Internet de forma segura.
#
# **Ejemplo práctico:**
# Si tu pod necesita descargar una imagen de Docker desde Docker Hub:
#
# * El pod está en una subnet privada.
# * Se usa un **NAT Gateway** para que pueda salir a Internet y descargar la imagen.
# * Nadie puede acceder al pod desde Internet directamente.
#
# ---
#
# ## **7: Tipo de cluster manual**
#
# **Pregunta:**
#
# > ¿Qué tipo de clúster OKE permite controlar completamente los nodos manualmente?
#
# **Tu respuesta:** Clúster gestionado (A)
# **Respuesta correcta:** Clúster autónomo / non-managed (B)
#
# **Concepto:**
#
# * **Clúster gestionado (Managed Cluster):**
#
#   * OCI administra los nodos automáticamente.
#   * No necesitas preocuparte por actualizar o escalar nodos; puedes usar **autoscaling**.
# * **Clúster autónomo / non-managed:**
#
#   * Tú eres responsable de **gestionar los nodos**: crear, escalar, actualizar, o reemplazar.
#   * Esto da **control total**, pero también más responsabilidad y tareas operativas.
#
# **Ejemplo práctico:**
#
# * Si quieres experimentar con **versiones personalizadas de Kubernetes** o manejar los nodos de forma muy específica, eliges **non-managed**.
# * Si quieres simplicidad y que OCI haga la mayor parte del trabajo, eliges **managed**.
#
# ---

# %% [markdown]
# ---
#
# ## **8: ¿Los Conteiner necesitan Clusters?**
# **Pregunta:**
# > Los Container Instances requieren un clúster de Kubernetes para funcionar.
#
# **Concepto:**
# - **Container Instances** permiten ejecutar contenedores de forma **aislada y sin necesidad de un clúster**.
# - Esto los diferencia de OKE, donde los contenedores siempre corren dentro de un clúster de Kubernetes.
# - Ventaja: puedes desplegar rápidamente cargas de trabajo ligeras sin configurar nodos, clusters o gestionar Kubernetes.
#
# **Ejemplo:**
# Si quieres ejecutar un script o microservicio temporal, puedes lanzar un Container Instance directamente, sin tocar OKE ni crear pods.
#
# ---
#
# ## **9: Ventajas de Cointeners**
# **Pregunta:**
# > ¿Cuál es la principal ventaja de usar Container Instances?
#
# **Respuesta correcta:** No necesitas administrar servidores o clústeres
#
# **Concepto:**
# - La **ventaja principal** es la simplicidad: **no administras servidores ni clústeres**, los contenedores se ejecutan directamente sobre la infraestructura de OCI.
# - El **autoscaling automático** no es la característica principal; Container Instances son más para cargas ligeras y temporales, no para aplicaciones de producción con alta demanda.
#
# **Ejemplo:**
# Desplegar un contenedor que hace un cálculo o procesa un archivo grande, y luego se destruye automáticamente, sin que tengas que configurar nodos o balanceadores.
#
# ---
#
# ## **10: Cointeners sin sistemas operativos**
# **Pregunta:**
# > Puedes usar Container Instances para ejecutar aplicaciones sin necesidad de instalar un sistema operativo completo en la máquina.
#
# **Tu respuesta:** Falso
# **Respuesta correcta:** Verdadero
#
# **Concepto:**
# - Un Container Instance ejecuta **contenedores directamente sobre la infraestructura de OCI**, usando el kernel subyacente, sin requerir que instales un sistema operativo completo en una VM.
# - Esto es diferente a crear una VM donde instalarías Docker manualmente.
#
# **Ejemplo:**
# - Si solo quieres ejecutar un contenedor con Python o Node.js, no necesitas crear una VM, instalar SO y Docker.
# - Solo lanzas un Container Instance, cargas tu imagen y corre inmediatamente.
#
# ---

# %% [markdown]
# # Oracle Functions

# %% [markdown]
# ¡Perfecto, Luis! 🙌
# Vamos a desmenuzar los **conceptos clave** detrás de las preguntas 1, 2, 3 y 4 sobre **Oracle Functions** para que los entiendas a fondo:
#
# ---
#
# ## **1. ¿Qué es Oracle Functions?**
#
# 👉 Es un servicio **serverless** en OCI.
#
# * **Serverless** significa que no te preocupas por servidores, escalado, ni administración de infraestructura.
# * Tú solo subes tu **código** (la función), y OCI lo ejecuta cuando se necesite.
# * Está empaquetado como un **contenedor** (Docker) para ser más portátil y seguro.
#
# 🔑 **Idea clave:** Oracle Functions te permite ejecutar **código bajo demanda**, pagando solo por el tiempo en que corre.
#
# ---
#
# ## **2. Basado en Fn Project**
#
# 👉 Oracle Functions se construye sobre **Fn Project**, que es un proyecto **open source** para funciones serverless.
#
# * Esto significa que no es una tecnología cerrada, puedes usar Fn en otras nubes o localmente.
# * Gracias a esto, Oracle Functions hereda la flexibilidad de Fn y sigue estándares abiertos.
#
# 🔑 **Idea clave:** No estás atado solo a OCI; puedes usar el mismo framework (Fn Project) fuera de Oracle.
#
# ---
#
# ## **3. Lenguajes soportados**
#
# 👉 Oracle Functions es **multi-lenguaje**: soporta varios lenguajes como:
#
# * **Java**
# * **Python**
# * **Node.js**
# * **Go**
# * **Ruby** (y otros que Fn puede soportar)
#
# Esto da libertad a los equipos de desarrollo para trabajar en el lenguaje que ya conocen.
#
# 🔑 **Idea clave:** Puedes programar funciones en distintos lenguajes, no estás limitado a uno solo.
#
# ---
#
# ## **4. Almacenamiento de imágenes en OCI Container Registry (OCIR)**
#
# 👉 Cada función que despliegas en Oracle Functions se empaqueta como una **imagen de contenedor (Docker)**.
#
# * Estas imágenes se guardan en **OCI Container Registry (OCIR)**, que es un repositorio privado de imágenes dentro de OCI.
# * Cuando invocas una función, OCI la descarga de OCIR y la ejecuta.
#
# 🔑 **Idea clave:** Las funciones son contenedores, y OCIR es el lugar donde se guardan para su despliegue.
#
# ---
#
# 📌 En resumen:
#
# 1. **Oracle Functions = Serverless** (ejecuta código sin servidores visibles).
# 2. **Fn Project = base open source** que da portabilidad y estándares.
# 3. **Soporta varios lenguajes** → flexibilidad para desarrolladores.
# 4. **Usa OCIR** para almacenar las imágenes de funciones como contenedores.
